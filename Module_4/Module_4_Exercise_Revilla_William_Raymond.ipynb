# %% [markdown]
# # Data Visualization Exercise
#
# For this exercise, use your creativity and understanding of the different concepts of data visualization.
#
# Create a plot (or a series of subplots) from whatever dataset you choose. As much as possible, please choose a dataset of relevance for visual storytelling. Make the plot using `python`. It doesn't matter if you choose to use `matplotlib` or `seaborn`.
#
# For the submission:
# 1. Upload the code that generates the plot to your GitHub repository or to Google Classroom (whichever method you're using for submissions).
# 2. Upload a png file of the visualization to Google Classroom and write in the Private Comments the caption for the figure you submitted.
# 3. Make sure to provide the data source in the same folder.
#
# Please make an effort to make it a good and compelling graphic. Choose your colors according to the type of data you're visualizing. Make sure to label everything and avoid clutter.
#
# As a reference for color choices, you can go to [CARTOColors](https://carto.com/carto-colors/). Simply click on the color map of your choice and it will copy the HEX code of the color.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Data Source
#
# Edit this cell to place the direct link to your data source.
#
# You may use the datasets you've downloaded for your project as your submission for this assignment.

# %%
# Read in data
data = pd.read_csv("chess_games_lichess.csv")

# %%
datacopy1 = data.copy()

# %%
data
# Out:
#              id  rated    created_at  last_move_at  turns victory_status  \
# 0      TZJHLljE  False  1.504210e+12  1.504210e+12     13      outoftime
# 1      l1NXvwaE   True  1.504130e+12  1.504130e+12     16         resign
# 2      mIICvQHh   True  1.504130e+12  1.504130e+12     61           mate
# 3      kWKvrqYL   True  1.504110e+12  1.504110e+12     61           mate
# 4      9tXo1AUZ   True  1.504030e+12  1.504030e+12     95           mate
# ...         ...    ...           ...           ...    ...            ...
# 20053  EfqH7VVH   True  1.499791e+12  1.499791e+12     24         resign
# 20054  WSJDhbPl   True  1.499698e+12  1.499699e+12     82           mate
# 20055  yrAas0Kj   True  1.499698e+12  1.499698e+12     35           mate
# 20056  b0v4tRyF   True  1.499696e+12  1.499697e+12    109         resign
# 20057  N8G2JHGG   True  1.499643e+12  1.499644e+12     78           mate
#
#       winner increment_code       white_id  white_rating            black_id  \
# ...

# %%
# Perform your data wrangling and descriptive stats to help

# %%
filtered_data = data.drop(columns=['id', 'rated','created_at','last_move_at','increment_code','white_id','black_id'])

# %%
filtered_data
#Removed unnecessary columns
# Out:
#        turns victory_status winner  white_rating  black_rating  \
# 0         13      outoftime  white          1500          1191
# 1         16         resign  black          1322          1261
# 2         61           mate  white          1496          1500
# 3         61           mate  white          1439          1454
# 4         95           mate  white          1523          1469
# ...      ...            ...    ...           ...           ...
# 20053     24         resign  white          1691          1220
# 20054     82           mate  black          1233          1196
# 20055     35           mate  white          1219          1286
# 20056    109         resign  white          1360          1227
# 20057     78           mate  black          1235          1339
#
#                                                    moves opening_eco  \
# 0      d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# ...

# %%
data['white_rating'].plot.hist(color='green')
plt.xlabel('Rating')
# Out:
# Text(0.5, 0, 'Rating')

# %%
data['black_rating'].plot.hist(color='red')
plt.xlabel('Rating')
# Out:
# Text(0.5, 0, 'Rating')

# %%
x = data['white_rating']
y = data['black_rating']
plt.hist([x,y], label = ['white','black'])
plt.legend(loc='upper right')
plt.show()

# %%
data.groupby('winner').size().plot.bar(color = ['C2','C3','C4'])
plt.xlabel('Winner by result')
# Out:
# Text(0.5, 0, 'Winner by result')

# %%
filtered_data_copy1 = filtered_data.copy()

# %%
filtered_data_copy1['opening_eco'].value_counts()[0:20].plot(kind='bar',colormap = 'Paired')
plt.xlabel('Opening Eco Code')
# Out:
# Text(0.5, 0, 'Opening Eco Code')

# %%
filtered_data_copy2 = filtered_data.copy()

# %%
filtered_data_copy2['opening_ply'].mean()
# Out:
# 4.8169807558081565

# %%
filtered_data_copy2['turns'].mean()
# Out:
# 60.46599860404826

# %%
filtered_data_copy2['turns'].plot.hist()
plt.xlabel('Number of turns')
# Out:
# Text(0.5, 0, 'Number of turns')

# %%
filtered_data_copy3 = filtered_data.copy()

# %%
filtered_data_copy3['Opening_eco_first_letter'] = filtered_data_copy3['opening_eco'].astype(str).str[0]

# %%
filtered_data_copy3
# Out:
#        turns victory_status winner  white_rating  black_rating  \
# 0         13      outoftime  white          1500          1191
# 1         16         resign  black          1322          1261
# 2         61           mate  white          1496          1500
# 3         61           mate  white          1439          1454
# 4         95           mate  white          1523          1469
# ...      ...            ...    ...           ...           ...
# 20053     24         resign  white          1691          1220
# 20054     82           mate  black          1233          1196
# 20055     35           mate  white          1219          1286
# 20056    109         resign  white          1360          1227
# 20057     78           mate  black          1235          1339
#
#                                                    moves opening_eco  \
# 0      d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# ...

# %%
filtered_data_copy3['Opening_eco_first_letter'].value_counts()
# Out:
# C    7658
# B    5238
# A    3973
# D    2683
# E     506
# Name: Opening_eco_first_letter, dtype: int64

# %%
filtered_data_copy3
# Out:
#        turns victory_status winner  white_rating  black_rating  \
# 0         13      outoftime  white          1500          1191
# 1         16         resign  black          1322          1261
# 2         61           mate  white          1496          1500
# 3         61           mate  white          1439          1454
# 4         95           mate  white          1523          1469
# ...      ...            ...    ...           ...           ...
# 20053     24         resign  white          1691          1220
# 20054     82           mate  black          1233          1196
# 20055     35           mate  white          1219          1286
# 20056    109         resign  white          1360          1227
# 20057     78           mate  black          1235          1339
#
#                                                    moves opening_eco  \
# 0      d4 d5 c4 c6 cxd5 e6 dxe6 fxe6 Nf3 Bb4+ Nc3 Ba5...         D10
# ...

# %%
filtered_data_copy3.groupby('Opening_eco_first_letter')['opening_eco'].count().plot.bar()
plt.xlabel('From volume of openings')
# Out:
# Text(0.5, 0, 'From volume of openings')

# %%
filtered_data_copy3.groupby(['opening_eco','Opening_eco_first_letter']).count()
# Out:
#                                       turns  victory_status  winner  \
# opening_eco Opening_eco_first_letter
# A00         A                          1007            1007    1007
# A01         A                           164             164     164
# A02         A                            82              82      82
# A03         A                            78              78      78
# A04         A                           285             285     285
# ...                                     ...             ...     ...
# E92         E                             5               5       5
# E94         E                             6               6       6
# E95         E                             1               1       1
# E97         E                             3               3       3
# E98         E                             2               2       2
#
#                                       white_rating  black_rating  moves  \
# opening_eco Opening_eco_first_letter
# ...

# %%
Aopenings = filtered_data_copy3[filtered_data_copy3['Opening_eco_first_letter']=='A']
Bopenings = filtered_data_copy3[filtered_data_copy3['Opening_eco_first_letter']=='B']
Copenings = filtered_data_copy3[filtered_data_copy3['Opening_eco_first_letter']=='C']
Dopenings = filtered_data_copy3[filtered_data_copy3['Opening_eco_first_letter']=='D']
Eopenings = filtered_data_copy3[filtered_data_copy3['Opening_eco_first_letter']=='E']

# %%
Aopenings = Aopenings[['Opening_eco_first_letter','opening_eco']]
Bopenings = Bopenings[['Opening_eco_first_letter','opening_eco']]
Copenings = Copenings[['Opening_eco_first_letter','opening_eco']]
Dopenings = Dopenings[['Opening_eco_first_letter','opening_eco']]
Eopenings = Eopenings[['Opening_eco_first_letter','opening_eco']]

# %%
Adf = Aopenings['opening_eco'].value_counts()[0:10]
Bdf = Bopenings['opening_eco'].value_counts()[0:10]
Cdf = Copenings['opening_eco'].value_counts()[0:10]
Ddf = Dopenings['opening_eco'].value_counts()[0:10]
Edf = Eopenings['opening_eco'].value_counts()[0:10]

# %%
Adf.plot.bar()

# %%
Bdf.plot.bar()

# %%
Cdf.plot.bar()

# %%
Ddf.plot.bar()

# %%
Edf.plot.bar()

# %% [markdown]
# Caption: This is a figure about....

# %% [markdown]
# # Plot chosen for presentation

# %%
filtered_data_copy1['opening_eco'].value_counts()[0:20].plot(kind='bar',colormap = 'Paired')
plt.xlabel('Opening Eco Code')
plt.savefig('Most_common_chess_William_REVILLA.png')

# %% [markdown]
# ### Figures above showed some popular chess openings from the different volumes from the "Encyclopaedia of Chess Openings". But the final figure shows the top 20 most popular openings from the data set.
#
# ###A00 Being the most common which is the called the Polish opening is interesting since I would argue that the most common opening is C20 being the King's Pawn opening which is ranked sixth in the data set. But in terms of first move, it could be seen that from Volume C is the most common which is the move E4 which is the movement of the King's pawn
